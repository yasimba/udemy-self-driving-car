# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam


np.random.seed(0)
points = 500
X = np.linspace(-3, 3, points)
#random value + y 
y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)#y=sin(x)+variance

model = Sequential()
#we only need x input to make the prediction and therefore should be the dimension
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))
adam = Adam(lr=0.01)
model.compile(loss='mse', optimizer=adam)
model.fit(X, y, epochs=50)
predictions = model.predict(X)

plt.scatter(X, y)
plt.plot(X, predictions, 'ro')
plt.show()
# Out:
# Epoch 1/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4473
# Epoch 2/50
# 500/500 [==============================] - 0s 415us/step - loss: 0.2372
# Epoch 3/50
# 500/500 [==============================] - 0s 419us/step - loss: 0.2664
# Epoch 4/50
# 500/500 [==============================] - 0s 424us/step - loss: 0.2270
# Epoch 5/50
# 500/500 [==============================] - 0s 445us/step - loss: 0.2282
# Epoch 6/50
# 500/500 [==============================] - 0s 433us/step - loss: 0.2260
# Epoch 7/50
# 500/500 [==============================] - 0s 405us/step - loss: 0.2193
# Epoch 8/50
# 500/500 [==============================] - 0s 419us/step - loss: 0.2218
# Epoch 9/50
# 500/500 [==============================] - 0s 435us/step - loss: 0.2063
# Epoch 10/50
# 500/500 [==============================] - 0s 429us/step - loss: 0.1923
# Epoch 11/50
# 500/500 [==============================] - 0s 517us/step - loss: 0.1924
# Epoch 12/50
# 500/500 [==============================] - 0s 395us/step - loss: 0.1792
# Epoch 13/50
# 500/500 [==============================] - 0s 411us/step - loss: 0.1701
# Epoch 14/50
# 500/500 [==============================] - 0s 516us/step - loss: 0.1596
# Epoch 15/50
# 500/500 [==============================] - 0s 434us/step - loss: 0.1571
# Epoch 16/50
# 500/500 [==============================] - 0s 409us/step - loss: 0.1467
# Epoch 17/50
# 500/500 [==============================] - 0s 414us/step - loss: 0.1408
# Epoch 18/50
# 500/500 [==============================] - 0s 375us/step - loss: 0.1329
# Epoch 19/50
# 500/500 [==============================] - 0s 485us/step - loss: 0.1236
# Epoch 20/50
# 500/500 [==============================] - 0s 427us/step - loss: 0.1281
# Epoch 21/50
# 500/500 [==============================] - 0s 470us/step - loss: 0.1189
# Epoch 22/50
# 500/500 [==============================] - 0s 394us/step - loss: 0.1175
# Epoch 23/50
# 500/500 [==============================] - 0s 453us/step - loss: 0.1191
# Epoch 24/50
# 500/500 [==============================] - 0s 497us/step - loss: 0.1172
# Epoch 25/50
# 500/500 [==============================] - 0s 420us/step - loss: 0.1111
# Epoch 26/50
# 500/500 [==============================] - 0s 392us/step - loss: 0.1081
# Epoch 27/50
# 500/500 [==============================] - 0s 337us/step - loss: 0.1111
# Epoch 28/50
# 500/500 [==============================] - 0s 510us/step - loss: 0.1242
# Epoch 29/50
# 500/500 [==============================] - 0s 397us/step - loss: 0.1237
# Epoch 30/50
# 500/500 [==============================] - 0s 441us/step - loss: 0.1127
# Epoch 31/50
# 500/500 [==============================] - 0s 347us/step - loss: 0.1077
# Epoch 32/50
# 500/500 [==============================] - 0s 413us/step - loss: 0.1144
# Epoch 33/50
# 500/500 [==============================] - 0s 587us/step - loss: 0.1079
# Epoch 34/50
# 500/500 [==============================] - 0s 412us/step - loss: 0.1110
# Epoch 35/50
# 500/500 [==============================] - 0s 410us/step - loss: 0.1045
# Epoch 36/50
# 500/500 [==============================] - 0s 399us/step - loss: 0.1087
# Epoch 37/50
# 500/500 [==============================] - 0s 423us/step - loss: 0.1067
# Epoch 38/50
# 500/500 [==============================] - 0s 479us/step - loss: 0.1054
# Epoch 39/50
# 500/500 [==============================] - 0s 450us/step - loss: 0.1050
# Epoch 40/50
# 500/500 [==============================] - 0s 385us/step - loss: 0.1046
# Epoch 41/50
# 500/500 [==============================] - 0s 396us/step - loss: 0.1150
# Epoch 42/50
# 500/500 [==============================] - 0s 425us/step - loss: 0.1029
# Epoch 43/50
# 500/500 [==============================] - 0s 425us/step - loss: 0.1032
# Epoch 44/50
# 500/500 [==============================] - 0s 409us/step - loss: 0.1058
# Epoch 45/50
# 500/500 [==============================] - 0s 356us/step - loss: 0.1019
# Epoch 46/50
# 500/500 [==============================] - 0s 375us/step - loss: 0.1017
# Epoch 47/50
# 500/500 [==============================] - 0s 375us/step - loss: 0.1119
# Epoch 48/50
# 500/500 [==============================] - 0s 470us/step - loss: 0.1084
# Epoch 49/50
# 500/500 [==============================] - 0s 451us/step - loss: 0.1039
# Epoch 50/50
# 500/500 [==============================] - 0s 431us/step - loss: 0.1077
